# %% [markdown]
# Types of Data
#    Numerical Data
#    Categorical Data

# %%
# import the library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('default')

# %%
# plotting a simple function
price = [48000,54000,57000,49000,47000,45000]
year = [2015,2016,2017,2018,2019,2020]

plt.plot(year, price)
plt.xlabel("Year")
plt.ylabel("Price")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       2 price = [48000,54000,57000,49000,47000,45000]
#       3 year = [2015,2016,2017,2018,2019,2020]
# ----> 5 plt.plot(year, price)
#       6 plt.xlabel("Year")
#       7 plt.ylabel("Price")
#
# NameError: name 'plt' is not defined
